# %% [markdown]
# # Configuration
# To configure the application, edit the `CONFIG.py` file and its values.
# How to donfigure the applicaiton is described in the `README.md` file of this project.
#
# # Dependencies
# The project dependencies and used packages are defined in the `requirements.txt` file.
# It is important to note that the tensorflow version 2.3.1 is used.
# This is needed to enable the image augmentation used in this project.
#
# In the interactive terminal, use the command `pip install -r requirements.txt` to install the required packages.

# %% [markdown]
# ## Import packages
# Import the functions needed to preview data, augment data, and run the various machine learning algorithms MLP and CNN.

# %%
from data_processing.dataInfo import *
from models.CNN import *
from models.tuning.CNNHyperModel import *
from models.MLP import *
from models.tuning.MLPHyperModel import *

# %% [markdown]
# # Showcase data
#
# ## Data info
# ### 120 classes
# Information about the dataset containing all 120 classes from the original dataset.

# %%
print("Data statistics for data from all 120 classes")
get_data_statistic()
# Out:
# Data statistics for data from all 120 classes
# The minimum amount of data in the dataset is:
# 148
# The minimum amount of data in the dataset is:
# 252
#
# The average amount of data from the given dataset is:
# 171.5
#
# The total amount of data is:
# 20580

# %% [markdown]
# ### 40 classes
# Information about the dataset containing the 40 classes used for testing and written about in the report.

# %%
print("Data statistics for data from the first 40 classes")
get_data_statistic(class_count=40)
# Out:
# Data statistics for data from the first 40 classes
# The minimum amount of data in the dataset is:
# 148
# The minimum amount of data in the dataset is:
# 252
#
# The average amount of data from the given dataset is:
# 180.675
#
# The total amount of data is:
# 7227

# %% [markdown]
# ## Show original data
# The original data from the dataset can be visualized using the method below.
# It shows one exaple of an image from the 9 first dog breeds contained in the dataset, with respective labels.

# %%
show_data_examples(count=9)

# %% [markdown]
# ## Show augmented data

# %%
show_augmented_images(count=9)

# %% [markdown]
# # Augment data and save data
# The data is augmented using keras preprocessing.
# The method below augments the images and saves them to a directory "processed_images" under the "data" directory.

# %%
process_data()
# Out:
# 100% (109 of 109) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (133 of 133) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (181 of 181) |######################| Elapsed Time: 0:00:05 Time:  0:00:05
# 100% (108 of 108) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (154 of 154) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (136 of 136) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (141 of 141) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (124 of 124) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (124 of 124) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (172 of 172) |######################| Elapsed Time: 0:00:05 Time:  0:00:05
# 100% (126 of 126) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (140 of 140) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (135 of 135) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (123 of 123) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (115 of 115) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (110 of 110) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (113 of 113) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (107 of 107) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (108 of 108) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (157 of 157) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (131 of 131) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (135 of 135) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (136 of 136) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (141 of 141) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (108 of 108) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (144 of 144) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (167 of 167) |######################| Elapsed Time: 0:00:05 Time:  0:00:05
# 100% (116 of 116) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (112 of 112) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (118 of 118) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (131 of 131) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (124 of 124) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (129 of 129) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (122 of 122) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (124 of 124) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (133 of 133) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (118 of 118) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (113 of 113) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (142 of 142) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (145 of 145) |######################| Elapsed Time: 0:00:04 Time:  0:00:04
# 100% (27 of 27) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (45 of 45) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (26 of 26) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (38 of 38) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (35 of 35) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (30 of 30) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (30 of 30) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (43 of 43) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (31 of 31) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (35 of 35) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (30 of 30) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (28 of 28) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (27 of 27) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (28 of 28) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (26 of 26) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (27 of 27) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (39 of 39) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (32 of 32) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (35 of 35) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (27 of 27) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (36 of 36) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (41 of 41) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (28 of 28) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (27 of 27) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (29 of 29) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (32 of 32) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (30 of 30) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (32 of 32) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (30 of 30) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (30 of 30) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (33 of 33) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (29 of 29) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (28 of 28) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (35 of 35) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (36 of 36) |########################| Elapsed Time: 0:00:01 Time:  0:00:01
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (26 of 26) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (15 of 15) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (22 of 22) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (20 of 20) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (24 of 24) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (20 of 20) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (15 of 15) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (22 of 22) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (20 of 20) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (20 of 20) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (24 of 24) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (17 of 17) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (17 of 17) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (18 of 18) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (19 of 19) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (17 of 17) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (16 of 16) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (20 of 20) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (21 of 21) |########################| Elapsed Time: 0:00:00 Time:  0:00:00

# %% [markdown]
# # Models
# ## Configuration
# ... TODO: Explain
#
# ## CNN
# The CNN model can be found in the **``CNN.py``** file under the **``model``** directory.

# %%
CNN()

# %% [markdown]
# ## MLP
# The MLP model can be found in the **``MLP.py``** file under the **``model``** directory.

# %%
MLP()

# %% [markdown]
# # Model tuning
# ## CNN tuning
# The CNN model can be found in the **``CNN.py``** file under the **``model``** directory.

# %%
CNN_Hyper()()

# %%
MLP_Hyper()
